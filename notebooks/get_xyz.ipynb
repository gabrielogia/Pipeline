# %%
import pandas as pd
import os
from rdkit import Chem
from rdkit.Chem import AllChem
from tqdm import tqdm
import logging
from joblib import Parallel, delayed

# Set up logging to suppress UFFTYPER warnings and capture errors
logging.getLogger('rdkit').setLevel(logging.ERROR)  # Suppress RDKit warnings
logging.basicConfig(filename='xyz_generation_errors.log', level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Load and merge data
df = pd.read_csv('PubChem_compound_text_Acrylate.csv')
df = df.rename(columns={' cid': 'id'})
pub_chem_db = pd.read_csv('pubchem_db.txt', sep='\t', names=['id', 'smiles'])
df = df.merge(pub_chem_db, on='id')

# Create output directory if it doesn't exist
output_dir = 'xyz_files'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Function to write XYZ file
def write_xyz_file(mol, filename):
    conf = mol.GetConformer()
    num_atoms = mol.GetNumAtoms()
    with open(filename, 'w') as f:
        f.write(f"{num_atoms}\n")
        f.write(f"Molecule ID: {os.path.basename(filename).split('.')[0]}\n")
        for i in range(num_atoms):
            atom = mol.GetAtomWithIdx(i)
            pos = conf.GetAtomPosition(i)
            symbol = atom.GetSymbol()
            f.write(f"{symbol} {pos.x:.6f} {pos.y:.6f} {pos.z:.6f}\n")

# Function to process a single row
def process_row(row):
    mol_id = row['id']
    sml = row['smiles']
    
    try:
        # Create molecule from SMILES
        m = Chem.MolFromSmiles(sml, sanitize=True)
        if m is None:
            logging.error(f"Failed to create molecule for ID {mol_id} with SMILES {sml}")
            return f"Skipping ID {mol_id}: Invalid SMILES"
    
        # Add hydrogens
        m_h = Chem.AddHs(m)
    
        # Set up embedding parameters
        params = AllChem.ETKDGv3()
        params.useRandomCoords = True
        params.maxIterations = 1000
        params.numThreads = 1  # Use 1 thread per molecule to avoid RDKit threading issues
        params.randomSeed = 42
    
        # Embed molecule
        if AllChem.EmbedMolecule(m_h, params) == -1:
            logging.error(f"Embedding failed for ID {mol_id} with SMILES {sml}")
            return f"Skipping ID {mol_id}: Embedding failed"
    
        # Write .xyz file
        xyz_filename = os.path.join(output_dir, f"{mol_id}.xyz")
        write_xyz_file(m_h, xyz_filename)
        
    except Exception as e:
        logging.error(f"Error processing ID {mol_id} with SMILES {sml}: {str(e)}")
        return f"Skipping ID {mol_id}: Exception occurred - {str(e)}"

# Parallel processing with joblib
results = Parallel(n_jobs=-1, backend='loky')(
    delayed(process_row)(row) for _, row in tqdm(df.iterrows(), total=len(df), desc="Processing molecules")
)
# Out:
# Processing molecules:   1%|▋                                                                                                        | 60/9626 [00:00<01:31, 104.69it/s][16:50:23] UFFTYPER: Unrecognized charge state for atom: 0
# [16:50:23] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# Processing molecules:   2%|█▋                                                                                                      | 160/9626 [00:00<00:29, 317.17it/s][16:50:23] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16
UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:50:38] UFFTYPER: Unrecognized charge state for atom: 0
# [16:50:38] UFFTYPER: Unrecognized charge state for atom: 14
# [16:50:38] UFFTYPER: Unrecognized atom type: U_+4 (0)
# [16:50:38] UFFTYPER: Unrecognized hybridization for atom: 0
# [16:50:38] UFFTYPER: Unrecognized charge state for atom: 0
# [16:50:38] UFFTYPER: Unrecognized atom type: Yb+3 (0)
# Processing molecules:  73%|███████████████████████████████████████████████████████████████████████████▌                           | 7060/9626 [00:17<00:08, 303.05it/s]ERROR:root:Embedding failed for ID 131738181 with SMILES C[C@]12CC[C@@H](C1(C)C)CC2C(=C)C(=O)[O-].COC(=O)C=C
# [16:50:40] UFFTYPER: Unrecognized charge state for atom: 6
# Processing molecules:  75%|█████████████████████████████████████████████████████████████████████████████▎                         | 7220/9626 [00:17<00:08, 298.48it/s][16:50:40] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# ERROR:root:Embedding failed for ID 92004758 with SMILES C[C@]12CC[C@@H](C1(C)C)CC2C(=C)C(=O)[O-]
# ERROR:root:Embedding failed for ID 131728765 with SMILES C[C@]12CC[C@@H](C1(C)C)CC2C(=C)C(=O)[O-].COC(=O)C=C.C=CC(=O)O
# Processing molecules:  75%|█████████████████████████████████████████████████████████████████████████████▌                         | 7252/9626 [00:18<00:09, 239.32it/s][16:50:40] UFFTYPER: Unrecognized charge state for atom: 1
# Processing molecules:  76%|██████████████████████████████████████████████████████████████████████████████                         | 7300/9626 [00:18<00:09, 234.79it/s]ERROR:root:Embedding failed for ID 131723422 with SMILES C[C@]12CC[C@@H](C1(C)C)CC2C(=C)C(=O)[O-].CC(C)(C)OC1=CC=C(C=C1)C=C
# Processing molecules:  81%|███████████████████████████████████████████████████████████████████████████████████▉                   | 7840/9626 [00:19<00:04, 422.11it/s][16:50:42] UFFTYPER: Unrecognized atom type: Zr1 (0)
# Processing molecules:  90%|████████████████████████████████████████████████████████████████████████████████████████████▍          | 8640/9626 [00:21<00:02, 342.86it/s][16:50:44] UFFTYPER: Unrecognized charge state for atom: 11
# Processing molecules:  97%|████████████████████████████████████████████████████████████████████████████████████████████████████▏  | 9360/9626 [00:24<00:00, 359.61it/s]ERROR:root:Embedding failed for ID 131723423 with SMILES C[C@]12CC[C@@H](C1(C)C)CC2C(=C)C(=O)[O-].C=CC1=CC=C(C=C1)O
# Processing molecules: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 9626/9626 [00:24<00:00, 389.43it/s]
# ERROR:root:Embedding failed for ID 134688658 with SMILES C=CC(=O)OC1C[C@@H]2CC[C@@H]1C2
# ERROR:root:Embedding failed for ID 51025217 with SMILES C=CC(=O)OCC1C[C@H]2C[C@H]1C=C2
# ERROR:root:Embedding failed for ID 131719376 with SMILES C[C@]12CC[C@@H](C1(C)C)CC2C(=C)C(=O)[O-].C=CC(=O)O
# ERROR:root:Embedding failed for ID 131723834 with SMILES CC(=C)C.C[C@]12CC[C@@H](C1(C)C)CC2C(=C)C(=O)[O-]
