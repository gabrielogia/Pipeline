# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_nm = pd.read_csv('reduced_molecules/7294/spec-nm.dat', sep=' ', names=['a', 'b'])
df_ev = pd.read_csv('reduced_molecules/7294/spec-ev.dat', sep=' ', names=['a', 'b'])

plt.figure(figsize=(15,5))
plt.plot(df_nm['a'], df_nm['b'])
plt.xlabel('Wavelength/nm')
plt.ylabel('Absorbance [abs. units]')
plt.xlim([df_nm['a'].min(), 600])
plt.xticks(np.linspace(df_nm['a'].min(), 600, 10))
plt.title('Absorbance - Methyl acrylate')
plt.show()

plt.figure(figsize=(15,5))
plt.plot(df_ev['a'], df_ev['b'])
plt.xlabel('e.v.')
plt.ylabel('Absorbance')
plt.title('Absorbance - Methyl acrylate')
plt.show()

# %%
df_nm = pd.read_csv('reduced_molecules/15621059/spec-nm.dat', sep=' ', names=['a', 'b'])
df_ev = pd.read_csv('reduced_molecules/15621059/spec-ev.dat', sep=' ', names=['a', 'b'])

plt.figure(figsize=(15,5))
plt.plot(df_nm['a'], df_nm['b'])
plt.xlabel('Wavelength/nm')
plt.ylabel('Absorbance [abs. units]')
plt.xlim([df_nm['a'].min(), 600])
plt.xticks(np.linspace(df_nm['a'].min(), 600, 10))
plt.title('Absorbance - Biphenylmethyl acrylate')
plt.show()

plt.figure(figsize=(15,5))
plt.plot(df_ev['a'], df_ev['b'])
plt.xlabel('e.v.')
plt.ylabel('Absorbance')
plt.title('Absorbance - Biphenylmethyl acrylate')
plt.show()

# %%
df_nm = pd.read_csv('reduced_molecules/75617/spec-nm.dat', sep=' ', names=['a', 'b'])
df_ev = pd.read_csv('reduced_molecules/75617/spec-ev.dat', sep=' ', names=['a', 'b'])

plt.figure(figsize=(15,5))
plt.plot(df_nm['a'], df_nm['b'])
plt.xlabel('Wavelength/nm')
plt.ylabel('Absorbance [abs. units]')
plt.xlim([df_nm['a'].min(), 600])
plt.xticks(np.linspace(df_nm['a'].min(), 600, 10))
plt.title('Absorbance - Benzyl acrylate')
plt.show()

plt.figure(figsize=(15,5))
plt.plot(df_ev['a'], df_ev['b'])
plt.xlabel('e.v.')
plt.ylabel('Absorbance')
plt.title('Absorbance - Benzyl acrylate')
plt.show()

# %%
df_nm = pd.read_csv('reduced_molecules/8821/spec-nm.dat', sep=' ', names=['a', 'b'])
df_ev = pd.read_csv('reduced_molecules/8821/spec-ev.dat', sep=' ', names=['a', 'b'])

plt.figure(figsize=(15,5))
plt.plot(df_nm['a'], df_nm['b'])
plt.xlabel('Wavelength/nm')
plt.ylabel('Absorbance [abs. units]')
plt.xlim([df_nm['a'].min(), 600])
plt.xticks(np.linspace(df_nm['a'].min(), 1000, 10))
plt.title('Absorbance - Butyl acrylate')
plt.show()

plt.figure(figsize=(15,5))
plt.plot(df_ev['a'], df_ev['b'])
plt.xlabel('e.v.')
plt.ylabel('Absorbance')
plt.title('Absorbance - Butyl acrylate')
plt.show()
