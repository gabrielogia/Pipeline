# %%
import pandas as pd

# %%
df = pd.read_csv('PubChem_compound_text_Acrylate.csv')

# %%
df[df['canonicalsmiles'] == 'C=CC(=O)OCC1=CC=C(C=C1)C2=CC=CC=C2']
# Out:
#            cid                                           cmpdname  \
# 1225  15621059  2-Propenoic acid, [1,1'-biphenyl]-4-ylmethyl e...
#
#                                             cmpdsynonym      mw        mf  \
# 1225  54140-58-8|4-Biphenylylmethyl acrylate|2-prope...  238.28  C16H14O2
#
#       polararea  complexity  xlogp  heavycnt  hbonddonor  ...  gpidcnt  \
# 1225       26.3       271.0    3.8        18           0  ...      116
#
#       gpfamilycnt meshheadings  \
# 1225           42          NaN
#
#                                               annothits annothitcnt aids  \
# 1225  Chemical and Physical Properties|Classificatio...           3  NaN
#
#       cidcdate                                         sidsrcname  \
# 1225  20070212  BLD Pharm|Chemieliva Pharmaceutical Co., Ltd|C...
#
#                                                 depcatg  annotation
# 1225  Chemical Vendors|Curation Efforts|Governmental...         NaN
#
# [1 rows x 39 columns]

# %%
specific_mol = df[df['cmpdname'].str.lower().isin(['methyl acrylate', #ok
                                                   'ethyl acrylate',  #ok
                                                   '2,2,2-trifluoroethyl acrylate', #ok
                                                   'butyl acrylate', #ok
                                                   'benzyl acrylate', #ok
                                                   '4-bromophenyl acrylate', #ok
                                                   '2-phenoxyethyl acrylate', #ok 
                                                   "2-propenoic acid, [1,1'-biphenyl]-4-ylmethyl ester" #ok
                                                   ])]

# %%
specific_mol
# Out:
#            cid                                           cmpdname  \
# 3         8846                                     Butyl Acrylate
# 4         8821                                     Ethyl acrylate
# 5         7294                                    Methyl acrylate
# 42       39485                            2-Phenoxyethyl acrylate
# 115      75617                                    Benzyl acrylate
# 229      67889                      2,2,2-Trifluoroethyl acrylate
# 1225  15621059  2-Propenoic acid, [1,1'-biphenyl]-4-ylmethyl e...
# 2644  13774217                             4-Bromophenyl acrylate
#
#                                             cmpdsynonym       mw        mf  \
# 3     BUTYL ACRYLATE|141-32-2|n-Butyl acrylate|butyl...  128.169   C7H12O2
# 4     ETHYL ACRYLATE|140-88-5|Acrylic acid ethyl est...  100.120    C5H8O2
# 5     METHYL ACRYLATE|96-33-3|Methyl prop-2-enoate|M...   86.090    C4H6O2
# ...

# %%
from rdkit import Chem

smlA = 'C=CC(=O)OCC1=CC=C(C=C1)C2=CC=CC=C2' # "2-Propenoic acid, [1,1'-biphenyl]-4-ylmethyl ester"
mA = Chem.MolFromSmiles(smlA)
mA

# %%
df_reduced = specific_mol[[' cid', 'cmpdname', 'canonicalsmiles']]
df_reduced = df_reduced.rename(columns={' cid': 'id', 'cmpdname': 'name', 'canonicalsmiles': 'smiles'})

# %%
df_reduced.to_csv('reduced_dataset.csv', index=False)
